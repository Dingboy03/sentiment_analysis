# %%
import requests

url = "http://127.0.0.1:8000/analyze"  # URL de ton serveur FastAPI

payload = {
    "text": "Je suis super content du service aujourd'hui !"
}

response = requests.post(url, json=payload)
print(response.json())
# Out:
# {'sentiment': 'positive', 'confidence': 0.938}
